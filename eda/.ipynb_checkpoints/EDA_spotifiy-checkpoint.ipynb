# %% [markdown]
# # EDA

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import openpyxl
import squarify
plt.rcParams.update(plt.rcParamsDefault)

# %%
df = pd.read_csv('../website/data/spotify_dataset.csv')

# %%
df.head()
# Out:
#    Index  Highest Charting Position  Number of Times Charted  \
# 0      1                          1                        8
# 1      2                          2                        3
# 2      3                          1                       11
# 3      4                          3                        5
# 4      5                          5                        1
#
#   Week of Highest Charting                          Song Name     Streams  \
# 0   2021-07-23--2021-07-30                            Beggin'  48,633,449
# 1   2021-07-23--2021-07-30          STAY (with Justin Bieber)  47,248,719
# 2   2021-06-25--2021-07-02                           good 4 u  40,162,559
# 3   2021-07-02--2021-07-09                         Bad Habits  37,799,456
# 4   2021-07-23--2021-07-30  INDUSTRY BABY (feat. Jack Harlow)  33,948,454
#
#            Artist Artist Followers                 Song ID  \
# 0        Måneskin          3377762  3Wrjm47oTz2sjIgck11l5e
# 1   The Kid LAROI          2230022  5HCyWlXZPP0y6Gqq8TgA20
# 2  Olivia Rodrigo          6266514  4ZtFanR9U6ndgddUvNcjcG
# 3      Ed Sheeran         83293380  6PQ88X9TkUIAUIZJHW2upE
# 4       Lil Nas X          5473565  27NovPIUIRrOZoCHxABJwK
#
#                                     Genre  ... Danceability Energy Loudness  \
# 0  ['indie rock italiano', 'italian pop']  ...        0.714    0.8   -4.808
# 1                  ['australian hip hop']  ...        0.591  0.764   -5.484
# 2                                 ['pop']  ...        0.563  0.664   -5.044
# 3                       ['pop', 'uk pop']  ...        0.808  0.897   -3.712
# 4           ['lgbtq+ hip hop', 'pop rap']  ...        0.736  0.704   -7.409
#
#   Speechiness Acousticness Liveness    Tempo Duration (ms) Valence  Chord
# 0      0.0504        0.127    0.359  134.002        211560   0.589      B
# 1      0.0483       0.0383    0.103  169.928        141806   0.478  C#/Db
# 2       0.154        0.335   0.0849  166.928        178147   0.688      A
# 3      0.0348       0.0469    0.364  126.026        231041   0.591      B
# 4      0.0615       0.0203   0.0501  149.995        212000   0.894  D#/Eb
#
# [5 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['Index', 'Highest Charting Position', 'Number of Times Charted',
#        'Week of Highest Charting', 'Song Name', 'Streams', 'Artist',
#        'Artist Followers', 'Song ID', 'Genre', 'Release Date', 'Weeks Charted',
#        'Popularity', 'Danceability', 'Energy', 'Loudness', 'Speechiness',
#        'Acousticness', 'Liveness', 'Tempo', 'Duration (ms)', 'Valence',
#        'Chord'],
#       dtype='object')

# %% [markdown]
# ### Genre formatting
# We see the genre is in a format not easily exploitable, so we change it.

# %%
df.Genre[:10]
# Out:
# 0    ['indie rock italiano', 'italian pop']
# 1                    ['australian hip hop']
# 2                                   ['pop']
# 3                         ['pop', 'uk pop']
# 4             ['lgbtq+ hip hop', 'pop rap']
# 5             ['lgbtq+ hip hop', 'pop rap']
# 6                      ['dance pop', 'pop']
# 7       ['puerto rican pop', 'trap latino']
# 8     ['latin', 'reggaeton', 'trap latino']
# 9    ['indie rock italiano', 'italian pop']
# Name: Genre, dtype: object

# %%
# extract genres
import re
df.Genre = df.Genre.apply(lambda x : str(x).strip("[]"))
df.Genre = df.Genre.apply(lambda x : str(x).rstrip(' \ '' '))
df.Genre = df.Genre.replace(" 'pop'","'pop'")
df.Genre = df.Genre.apply(lambda x : re.sub("'","",x)) 
df.Genre = df.Genre.apply(lambda x : str(x).lstrip(' '))
df.Genre[:10]
# Out:
# 0    indie rock italiano, italian pop
# 1                  australian hip hop
# 2                                 pop
# 3                         pop, uk pop
# 4             lgbtq+ hip hop, pop rap
# 5             lgbtq+ hip hop, pop rap
# 6                      dance pop, pop
# 7       puerto rican pop, trap latino
# 8       latin, reggaeton, trap latino
# 9    indie rock italiano, italian pop
# Name: Genre, dtype: object

# %%
genre_counts = {}
for idx,r in df.iterrows():
    for x in r.Genre.split(','):
        tmp = x.strip()
        if(tmp not in genre_counts):
            genre_counts[tmp] = 1
        else:
            genre_counts[tmp] += 1
            
genre_counts
# Out:
# {'indie rock italiano': 4,
#  'italian pop': 11,
#  'australian hip hop': 9,
#  'pop': 485,
#  'uk pop': 52,
#  'lgbtq+ hip hop': 8,
#  'pop rap': 164,
#  'dance pop': 257,
#  'puerto rican pop': 22,
#  'trap latino': 155,
#  'latin': 154,
#  'reggaeton': 157,
#  'reggaeton colombiano': 45,
#  'k-pop': 45,
#  'k-pop boy group': 30,
#  'canadian pop': 85,
#  'post-teen pop': 256,
#  'canadian contemporary r&b': 24,
#  'gauze pop': 1,
#  'indietronica': 2,
#  'shiver pop': 1,
#  'latin hip hop': 17,
#  'dfw rap': 10,
#  'melodic rap': 124,
#  'rap': 310,
#  'house': 7,
#  'pop dance': 54,
#  'tropical house': 45,
#  'uk dance': 9,
#  'electropop': 60,
#  'colombian pop': 18,
#  '': 86,
#  'chicago rap': 47,
#  'panamanian pop': 9,
#  'latin pop': 15,
#  'pop argentino': 1,
#  'big room': 1,
#  'brostep': 4,
#  'dutch edm': 4,
#  'edm': 50,
#  'electro house': 10,
#  'slap house': 17,
#  'trance': 2,
#  'cali rap': 9,
#  'trap argentino': 10,
#  'argentine hip hop': 8,
#  'pop venezolano': 6,
#  'progressive electro house': 4,
#  'dreamo': 1,
#  'indie surf': 1,
#  'surf punk': 1,
#  'vegas indie': 1,
#  'pop rock': 17,
#  'piano rock': 3,
#  'houston rap': 6,
#  'trap queen': 14,
#  'german dance': 6,
#  'german techno': 1,
#  'german trance': 1,
#  'r&b': 30,
#  'modern alternative rock': 4,
#  'modern rock': 23,
#  'canadian hip hop': 32,
#  'toronto rap': 30,
#  'brooklyn drill': 37,
#  'nyc rap': 8,
#  'aussietronica': 1,
#  'mexican hip hop': 1,
#  'rap conciencia': 1,
#  'australian pop': 11,
#  'hip hop': 151,
#  'comic': 2,
#  'melanesian pop': 1,
#  'pacific islands pop': 1,
#  'png pop': 1,
#  'canadian trap': 8,
#  'southern hip hop': 29,
#  'trap': 159,
#  'trap soul': 3,
#  'underground hip hop': 8,
#  'dutch pop': 1,
#  'german hip hop': 53,
#  'rap latina': 3,
#  'afrofuturism': 1,
#  'uk hip hop': 10,
#  'alt z': 20,
#  'rock': 32,
#  'latin viral pop': 1,
#  'chill r&b': 3,
#  'nyc pop': 1,
#  'progressive house': 6,
#  'sertanejo': 10,
#  'sertanejo pop': 9,
#  'sertanejo universitario': 12,
#  'viral pop': 18,
#  'north carolina hip hop': 30,
#  'bedroom pop': 4,
#  'indie pop': 7,
#  'folk-pop': 2,
#  'grunge': 1,
#  'permanent wave': 11,
#  'pop soul': 3,
#  'irish singer-songwriter': 1,
#  'classic rock': 12,
#  'glam rock': 4,
#  'pop house': 3,
#  'new french touch': 2,
#  'plugg': 2,
#  'vapor trap': 5,
#  'viral rap': 8,
#  'forro': 7,
#  'art pop': 5,
#  'norwegian pop': 1,
#  'dance rock': 1,
#  'album rock': 8,
#  'art rock': 4,
#  'mellow gold': 11,
#  'new wave': 3,
#  'soft rock': 10,
#  'yacht rock': 3,
#  'talent show': 9,
#  'urban contemporary': 7,
#  'sad rap': 5,
#  'contemporary country': 13,
#  'country': 3,
#  'country road': 4,
#  'modern country rock': 2,
#  'neo soul': 2,
#  'funk bh': 1,
#  'funk carioca': 15,
#  'pop edm': 7,
#  'pop nacional': 5,
#  'detroit hip hop': 24,
#  'german alternative rap': 3,
#  'german drill': 6,
#  'german trap': 4,
#  'london rap': 3,
#  'italian hip hop': 7,
#  'neo mellow': 5,
#  'singer-songwriter': 3,
#  'funk ostentacao': 3,
#  'funk paulista': 2,
#  'queens hip hop': 3,
#  'sudanese pop': 1,
#  'k-pop girl group': 18,
#  'escape room': 6,
#  'reggaeton flow': 21,
#  'rave funk': 1,
#  'beatlesque': 5,
#  'britpop': 2,
#  'madchester': 2,
#  'dmv rap': 4,
#  'eau claire indie': 1,
#  'folktronica': 1,
#  'miami hip hop': 12,
#  'metropopolis': 3,
#  'nz pop': 4,
#  'frauenrap': 3,
#  'german pop': 7,
#  'garage rock': 2,
#  'sheffield indie': 2,
#  'atl hip hop': 53,
#  'italian adult pop': 2,
#  'francoton': 7,
#  'french hip hop': 10,
#  'pop urbaine': 10,
#  'rap francais': 7,
#  'rap marseille': 2,
#  'conscious hip hop': 18,
#  'emo rap': 12,
#  'seattle hip hop': 1,
#  'ohio hip hop': 18,
#  'dembow': 2,
#  'dominican pop': 3,
#  'rap dominicano': 2,
#  'alternative metal': 1,
#  'nu metal': 1,
#  'post-grunge': 1,
#  'rap metal': 1,
#  'funk 150 bpm': 1,
#  'atl trap': 13,
#  'rap conscient': 5,
#  'eurovision': 3,
#  'nouvelle chanson francaise': 1,
#  'hip pop': 5,
#  'oulu metal': 1,
#  'trancecore': 1,
#  'boston hip hop': 1,
#  'bubblegrunge': 1,
#  'chicago indie': 1,
#  'dream smp': 2,
#  'icelandic pop': 1,
#  'sunnlensk tonlist': 1,
#  'uk alternative pop': 1,
#  'indie cafe pop': 9,
#  'bedroom soul': 2,
#  'hamburg hip hop': 11,
#  'weirdcore': 1,
#  'funk pop': 4,
#  'pagode baiano': 3,
#  'memphis hip hop': 4,
#  'tennessee hip hop': 1,
#  'alternative r&b': 14,
#  'piseiro': 5,
#  'east coast hip hop': 2,
#  'gangster rap': 4,
#  'hardcore hip hop': 2,
#  'trap triste': 3,
#  'vancouver indie': 1,
#  'deep underground hip hop': 3,
#  'kentucky hip hop': 4,
#  'new romantic': 2,
#  'new wave pop': 5,
#  'synthpop': 2,
#  'electronic trap': 4,
#  'australian dance': 5,
#  'deep euro house': 3,
#  'deep house': 3,
#  'australian psych': 5,
#  'neo-psychedelic': 5,
#  'indie poptimism': 7,
#  'indonesian pop': 1,
#  'italian indie pop': 1,
#  'italian pop rock': 1,
#  'trap boricua': 9,
#  'old school rap francais': 1,
#  'urbano espanol': 3,
#  'rhode island rap': 2,
#  'etherpop': 4,
#  'modern indie pop': 3,
#  'social media pop': 4,
#  'melodic metalcore': 2,
#  'metalcore': 2,
#  'uk metalcore': 2,
#  'brazilian hip hop': 1,
#  'cubaton': 1,
#  'tekk': 1,
#  'cumbia pop': 1,
#  'disco': 2,
#  'europop': 3,
#  'adult standards': 18,
#  'brill building pop': 3,
#  'easy listening': 12,
#  'lounge': 17,
#  'rockabilly': 3,
#  'vocal jazz': 11,
#  'jazz pop': 3,
#  'musical advocacy': 1,
#  'folk rock': 2,
#  'soul': 5,
#  'swing': 2,
#  'american folk revival': 1,
#  'celtic': 1,
#  'celtic punk': 1,
#  'celtic rock': 1,
#  'folk punk': 1,
#  'irish folk': 1,
#  'punk': 1,
#  'classic uk pop': 1,
#  'rock-and-roll': 2,
#  'eurodance': 1,
#  'boy band': 14,
#  'hollywood': 1,
#  'show tunes': 1,
#  'motown': 3,
#  'torch song': 1,
#  'soundtrack': 1,
#  'heartland rock': 2,
#  'british soul': 2,
#  'a cappella': 1,
#  'chicago soul': 1,
#  'classic soul': 1,
#  'funk': 2,
#  'quiet storm': 2,
#  'southern soul': 1,
#  'country rock': 1,
#  'trap italiana': 5,
#  'uk funky': 1,
#  'mariachi': 2,
#  'nuevo regional mexicano': 2,
#  'ranchera': 2,
#  'regional mexican': 3,
#  'south african house': 1,
#  'basshall': 3,
#  'pop r&b': 2,
#  'afroswing': 2,
#  'uk alternative hip hop': 1,
#  'girl group': 2,
#  'canadian latin': 1,
#  'champeta': 1,
#  'electro latino': 1,
#  'australian rock': 1,
#  'hard rock': 2,
#  'indie pop rap': 2,
#  'oakland hip hop': 2,
#  'r&b en espanol': 6,
#  'pop reggaeton': 3,
#  'trap chileno': 1,
#  'west coast rap': 1,
#  'jazz funk': 1,
#  'belgian hip hop': 2,
#  'rap belge': 2,
#  'r&b brasileiro': 1,
#  'rap cearense': 1,
#  'trap brasileiro': 1,
#  'scandipop': 1,
#  'swedish pop': 1,
#  'indie r&b': 1,
#  'jawaiian': 1,
#  'florida rap': 3,
#  'acoustic pop': 1,
#  'german cloud rap': 7,
#  'perreo': 1,
#  'christlicher rap': 1,
#  'philly rap': 34,
#  'indie rockism': 1,
#  'german underground rap': 1,
#  'k-rap': 1,
#  'chicago drill': 1,
#  'drill': 1,
#  'banda': 1,
#  'corrido': 1,
#  'norteno': 1,
#  'alternative pop rock': 1,
#  'minnesota hip hop': 3,
#  'albanian hip hop': 2,
#  'venezuelan hip hop': 1,
#  'meme rap': 1,
#  'grime': 1,
#  'brega funk': 2,
#  'moombahton': 1,
#  'pittsburgh rap': 11,
#  'new orleans rap': 1,
#  'deep german hip hop': 1,
#  'turkish trap': 1}

# %% [markdown]
# We have created a dictionary mapping each genre to the number of times it appears.

# %% [markdown]
# ### Release date formatting
# it is not in a datetime format, because of some null values so we clean it.

# %%
df['Release Date']
# Out:
# 0       2017-12-08
# 1       2021-07-09
# 2       2021-05-21
# 3       2021-06-25
# 4       2021-07-23
#            ...
# 1551    2017-06-02
# 1552    2019-10-11
# 1553    2018-01-12
# 1554    2019-09-25
# 1555    2019-11-13
# Name: Release Date, Length: 1556, dtype: object

# %%
len(df[df['Release Date'].isnull()])
# Out:
# 0

# %%
len(df[df['Release Date']==' '])
# Out:
# 11

# %% [markdown]
# No null release dates, but eleven with no value so we remove them

# %%
df = df[df['Release Date'] != ' ']

# %%
#convert to datetime
df['Release Date'] = df['Release Date'].apply(lambda x : pd.to_datetime(x))

# %%
df['Release Date']
# Out:
# 0      2017-12-08
# 1      2021-07-09
# 2      2021-05-21
# 3      2021-06-25
# 4      2021-07-23
#           ...
# 1551   2017-06-02
# 1552   2019-10-11
# 1553   2018-01-12
# 1554   2019-09-25
# 1555   2019-11-13
# Name: Release Date, Length: 1545, dtype: datetime64[ns]

# %% [markdown]
# ### index
# The index is uniquely identifying so we set it as the index of the table

# %%
df.Index.is_unique
# Out:
# True

# %%
df = df.set_index('Index')

# %% [markdown]
# ### highest charting position

# %%
df['Highest Charting Position'].hist(bins=20)
plt.title('Highest Charting Position')
plt.xlabel('Charting position')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Streams formatting

# %%
df.Streams.describe()
# Out:
# count           1545
# unique          1545
# top       48,633,449
# freq               1
# Name: Streams, dtype: object

# %% [markdown]
# There are not in a float format, we convert it

# %%
df.Streams = df.Streams.apply(lambda x : x.replace(',',''))
df.Streams = df.Streams.apply(lambda x : int(x))

# %%
df.Streams.describe()
# Out:
# count    1.545000e+03
# mean     6.337136e+06
# std      3.375402e+06
# min      4.176083e+06
# 25%      4.915080e+06
# 50%      5.269163e+06
# 75%      6.452492e+06
# max      4.863345e+07
# Name: Streams, dtype: float64

# %%
df['Streams'].hist(bins=40)
plt.title('Streams')
plt.xlabel('Stream count')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Song id

# %%
len(df[df['Song ID'].isnull()])
# Out:
# 0

# %%
len(df[df['Song ID']==' '])
# Out:
# 0

# %%
df['Song ID'].is_unique
# Out:
# False

# %% [markdown]
# We see the Song ID is not unique to each song, which is surprising.

# %% [markdown]
# Indeed, there are several songs with duplicated song ID :

# %%
df[df['Song ID'].duplicated()]
# Out:
#        Highest Charting Position  Number of Times Charted  \
# Index
# 64                             2                       34
# 101                           52                       19
# 145                           13                       83
# 224                           28                       23
# 275                           59                        6
# 318                          126                        1
# 364                           55                        1
# 377                           61                       17
# 408                           33                       24
# 474                           97                        9
# 545                           17                       15
# 553                          193                        1
# 578                          137                        1
# 736                           83                        2
# 815                           23                       27
# 882                           26                       35
# 936                           43                        2
# 989                           42                       24
# 1051                          72                        8
# 1138                          93                        1
# 1155                          54                       22
# 1194                          23                       20
# 1210                          85                        2
# 1236                          63                        6
# 1431                           7                        1
# 1436                          65                        7
# 1438                          45                        2
# 1544                          59                        1
# 1549                         178                        1
#
#       Week of Highest Charting  \
# Index
# 64      2021-02-26--2021-03-05
# 101     2020-03-27--2020-04-03
# 145     2020-04-24--2020-05-01
# 224     2021-04-16--2021-04-23
# 275     2021-05-28--2021-06-04
# 318     2021-06-04--2021-06-11
# 364     2021-05-14--2021-05-21
# 377     2020-12-04--2020-12-11
# 408     2021-01-08--2021-01-15
# 474     2021-02-12--2021-02-19
# 545     2020-11-06--2020-11-13
# 553     2021-02-12--2021-02-19
# 578     2021-01-22--2021-01-29
# 736     2020-11-27--2020-12-04
# 815     2020-07-31--2020-08-07
# 882     2020-06-12--2020-06-19
# 936     2020-08-21--2020-08-28
# 989     2020-04-17--2020-04-24
# 1051    2020-06-05--2020-06-12
# 1138    2020-05-29--2020-06-05
# 1155    2020-01-03--2020-01-10
# 1194    2020-01-24--2020-01-31
# 1210    2020-04-24--2020-05-01
# 1236    2020-03-13--2020-03-20
# 1431    2020-02-07--2020-02-14
# 1436    2019-12-27--2020-01-03
# 1438    2020-01-31--2020-02-07
# 1544    2019-12-27--2020-01-03
# 1549    2019-12-27--2020-01-03
#
#                                                Song Name   Streams  \
# Index
# 64                                       Save Your Tears   8843110
# 101                                           Levitating   6799831
# 145                                           goosebumps   5691540
# 224                                                  911   6111108
# 275                                              Poblado   6893939
# 318                                  Voice of the Heroes   6249801
# 364                                            c l o s e  10712648
# 377                                                 Body   5831357
# 408                                           Goosebumps   5496962
# 474                                    Esquema Preferido   5356696
# 545                                        Hawái - Remix   5163323
# 553                                           Wonderwall   4902737
# 578                                           Los Dioses   5929507
# 736    Wonderful Christmastime [Edited Version] - Rem...   9624871
# 815                                             Relación   4825749
# 882                                         WHATS POPPIN   4745752
# 936                                             Lemonade  11373347
# 989                                               Tattoo   4588064
# 1051                                  Deep End Freestyle   5280810
# 1138                                        Chromatica I   6630385
# 1155                         Goodbyes (Feat. Young Thug)   5134161
# 1194                                            Suicidal   4320116
# 1210                                            Emotions   4901960
# 1236   Oprah’s Bank Account (Lil Yachty & DaBaby feat...   4618744
# 1431                                          Intentions  28509534
# 1436          Good as Hell (feat. Ariana Grande) - Remix   6066001
# 1438                                              Get Me   5236560
# 1544                                          Trampoline   8896030
# 1549                                       Old Town Road   4852004
#
#                                         Artist Artist Followers  \
# Index
# 64                                  The Weeknd         35305637
# 101                                   Dua Lipa         27142474
# 145                               Travis Scott         17719446
# 224                                       Sech          8758283
# 275    Crissin, Totoy El Frio, Natan & Shander         29051363
# 318                         Lil Baby, Lil Durk          7805880
# 364                                    J. Cole         14097410
# 377                  Russ Millions, Tion Wayne           323203
# 408                                       HVME         17719446
# 474              DJ Ivis, Tarcísio do Acordeon           342930
# 545                         Maluma, The Weeknd         26784251
# 553                                      Oasis          6478565
# 578                            Anuel AA, Ozuna         18306226
# 736                             Paul McCartney          3609658
# 815                                       Sech          8766508
# 882                                Jack Harlow          3828418
# 936    Internet Money, Gunna, Don Toliver, NAV           412466
# 989                             Rauw Alejandro          6096559
# 1051                    Sleepy Hallow, Fousheé           411262
# 1138                                 Lady Gaga         18585963
# 1155                               Post Malone         33663701
# 1194                                 YNW Melly          6332535
# 1210                                    Ufo361          1700759
# 1236                                Lil Yachty          7358720
# 1431                      Justin Bieber, Quavo         48544923
# 1436                                     Lizzo          3991674
# 1438                    Justin Bieber, Kehlani         48544923
# 1544                               SHAED, ZAYN           139434
# 1549                                 Lil Nas X          5488666
#
#                       Song ID  \
# Index
# 64     37BZB0z9T8Xu7U3e65qxFy
# 101    463CkQjx2Zk1yXoBuierM9
# 145    5uEYRdEIh9Bo4fpjDd4Na9
# 224    27RSJHEA99Y0Vsow7nA37A
# 275    1WedZeiezCmCEOzLwhx0hV
# 318    4lUmnwRybYH7mMzf16xB0y
# 364    1D3z6HTiQsNmZxjl7F7eoG
# 377    6uvMKqNlrSvcC4NaKnrwjZ
# 408    5uEYRdEIh9Bo4fpjDd4Na9
# 474    0e6NlGJxYlHvAN8SKxad7N
# 545    0GzuHFG4Ql6DoyxFRnIk3F
# 553    7ygpwy2qP3NbrxVkHvUhXY
# 578    73O30uMI7n6DuzBmbtO7kC
# 736    1SV1fxF65n9NhRHp3KlBuu
# 815    35UUpTmrcFXNIVIN26ujXl
# 882    2MbdDtCv5LUVjYy9RuGTgC
# 936    02kDW379Yfd5PzW5A6vuGt
# 989    4ZRrLHqzhGRXYj2qcB4s5S
# 1051   2AlYncTpVHKwHb55F9lF6O
# 1138   0oQc0F6KUE7QY7k5TU6bic
# 1155   0t3ZvGKlmYmVsDzBJAXK8C
# 1194   4S2uhQE8L9V6p7rj7SiauJ
# 1210   3yZCjDTxzZxx1kll1sRjGc
# 1236   7wsmIIm0xWmtP7TmACXkJn
# 1431   4umIPjkehX1r7uhmGvXiSV
# 1436   07Oz5StQ7GRoygNLaXs2pd
# 1438   5VwwpU7KsLhgfbMEecedhJ
# 1544   1iQDltZqI7BXnHrFy4Qo1k
# 1549   2YpeDb67231RjR0MgVLzsG
#
#                                                    Genre Release Date  ...  \
# Index                                                                  ...
# 64          canadian contemporary r&b, canadian pop, pop   2021-04-23  ...
# 101                               dance pop, pop, uk pop   2020-10-01  ...
# 145                                      rap, slap house   2021-01-15  ...
# 224        latin, panamanian pop, reggaeton, trap latino   2021-07-09  ...
# 275               latin, reggaeton, reggaeton colombiano   2021-06-18  ...
# 318                     atl hip hop, atl trap, rap, trap   2021-06-04  ...
# 364    conscious hip hop, hip hop, north carolina hip...   2021-05-14  ...
# 377                                           london rap   2021-04-22  ...
# 408                                      rap, slap house   2021-01-15  ...
# 474                                              piseiro   2020-11-26  ...
# 545               latin, reggaeton, reggaeton colombiano   2020-11-05  ...
# 553    beatlesque, britpop, madchester, permanent wav...   1995-01-01  ...
# 578    latin, reggaeton, reggaeton flow, trap boricua...   2021-01-22  ...
# 736    album rock, art rock, beatlesque, classic rock...   1980-05-16  ...
# 815        latin, panamanian pop, reggaeton, trap latino   2020-09-04  ...
# 882    canadian hip hop, canadian trap, melodic rap, ...   2020-06-24  ...
# 936                                   pop rap, rap, trap   2020-08-14  ...
# 989                        puerto rican pop, trap latino   2020-07-09  ...
# 1051                             brooklyn drill, nyc rap   2020-06-05  ...
# 1138                       dance pop, pop, post-teen pop   2020-05-29  ...
# 1155                           dfw rap, melodic rap, rap   2019-09-06  ...
# 1194                                   melodic rap, trap   2020-03-13  ...
# 1210                    german cloud rap, german hip hop   2020-06-12  ...
# 1236   atl hip hop, hip hop, melodic rap, rap, trap, ...   2020-03-09  ...
# 1431                    canadian pop, pop, post-teen pop   2020-02-14  ...
# 1436   dance pop, escape room, minnesota hip hop, pop...   2016-01-01  ...
# 1438                    canadian pop, pop, post-teen pop   2020-02-14  ...
# 1544                                     electropop, pop   2019-09-26  ...
# 1549                             lgbtq+ hip hop, pop rap   2019-06-21  ...
#
#       Danceability Energy Loudness Speechiness Acousticness Liveness    Tempo  \
# Index
# 64            0.65  0.825   -4.645      0.0325       0.0215   0.0936  118.091
# 101          0.702  0.825   -3.787      0.0601      0.00883   0.0674  102.977
# 145          0.841  0.593   -7.846      0.0379        0.418    0.124  124.917
# 224          0.816   0.71   -3.728      0.0398        0.165    0.292    93.02
# 275          0.813  0.809   -5.382      0.0846        0.102    0.377   93.005
# 318          0.596   0.65   -5.167       0.337        0.138     0.14  133.997
# 364          0.597  0.587   -7.026       0.137       0.0622    0.214  140.021
# 377          0.883  0.674   -8.043       0.357         0.21   0.0678   141.02
# 408          0.841  0.593   -7.846      0.0379        0.418    0.124  124.917
# 474          0.676  0.823   -4.386       0.102        0.242   0.0773  160.013
# 545          0.766  0.788   -3.128       0.312        0.105    0.142  179.984
# 553          0.375  0.893   -4.097      0.0406     0.000509    0.187  174.323
# 578          0.817  0.737   -5.453       0.102        0.046    0.092   93.985
# 736          0.774  0.511   -8.914      0.0319        0.322   0.0672   94.736
# 815          0.793  0.771   -3.417      0.0959       0.0337    0.284  171.943
# 882          0.904  0.723   -5.224        0.26       0.0631    0.185  145.013
# 936          0.799   0.66   -6.153       0.079        0.256    0.111   140.04
# 989          0.848  0.637   -5.132       0.156       0.0413   0.0521   96.988
# 1051         0.868  0.479   -6.687       0.445        0.703    0.102  133.928
# 1138         0.184  0.297  -14.534      0.0359        0.473    0.527   75.824
# 1155         0.548  0.653   -3.875       0.081        0.456    0.103  150.068
# 1194         0.655  0.441   -5.245      0.0629        0.474    0.099  139.957
# 1210         0.788  0.491   -9.884       0.109        0.386    0.107   98.543
# 1236         0.836  0.617   -4.363      0.0534         0.17    0.319  138.066
# 1431         0.806  0.546   -6.637      0.0575          0.3    0.102  147.986
# 1436         0.668  0.892   -3.001      0.0645        0.298    0.735   95.927
# 1438         0.832  0.508   -6.913       0.149       0.0492    0.107  109.352
# 1544         0.619  0.459   -5.782      0.0334         0.56    0.137  126.803
# 1549         0.878  0.619    -5.56       0.102       0.0533    0.113  136.041
#
#       Duration (ms) Valence  Chord
# Index
# 64           191014   0.593      C
# 101          203064   0.915  F#/Gb
# 145          162803   0.808  C#/Db
# 224          208631   0.784      G
# 275          393280   0.646  D#/Eb
# 318          257428   0.188      A
# 364          218802  0.0753      G
# 377          278085    0.73      B
# 408          162803   0.808  C#/Db
# 474          190680   0.907      F
# 545          200482   0.609  F#/Gb
# 553          258773   0.434      D
# 578          206587    0.67  F#/Gb
# 736          227653   0.771      B
# 815          247308   0.835      F
# 882          227478   0.835      B
# 936          195429   0.471  C#/Db
# 989          222680   0.698      A
# 1051         115200   0.776      E
# 1138          41867   0.113      D
# 1155         174853   0.163      F
# 1194         225857   0.273      A
# 1210         146028   0.271  G#/Ab
# 1236         206702   0.866      C
# 1431         212867   0.874      A
# 1436         159011   0.478      F
# 1438         185427    0.75  F#/Gb
# 1544         184280   0.498      G
# 1549         157067   0.639  F#/Gb
#
# [29 rows x 22 columns]

# %%
# let's see for the first one
df[df['Song ID']=='37BZB0z9T8Xu7U3e65qxFy']
# Out:
#        Highest Charting Position  Number of Times Charted  \
# Index
# 18                             5                       14
# 64                             2                       34
#
#       Week of Highest Charting                                     Song Name  \
# Index
# 18      2021-04-23--2021-04-30  Save Your Tears (with Ariana Grande) (Remix)
# 64      2021-02-26--2021-03-05                               Save Your Tears
#
#         Streams      Artist Artist Followers                 Song ID  \
# Index
# 18     18053141  The Weeknd         35305637  37BZB0z9T8Xu7U3e65qxFy
# 64      8843110  The Weeknd         35305637  37BZB0z9T8Xu7U3e65qxFy
#
#                                               Genre Release Date  ...  \
# Index                                                             ...
# 18     canadian contemporary r&b, canadian pop, pop   2021-04-23  ...
# 64     canadian contemporary r&b, canadian pop, pop   2021-04-23  ...
#
#       Danceability Energy Loudness Speechiness Acousticness Liveness    Tempo  \
# Index
# 18            0.65  0.825   -4.645      0.0325       0.0215   0.0936  118.091
# 64            0.65  0.825   -4.645      0.0325       0.0215   0.0936  118.091
#
#       Duration (ms) Valence Chord
# Index
# 18           191014   0.593     C
# 64           191014   0.593     C
#
# [2 rows x 22 columns]

# %% [markdown]
# Indeed it is almost the same songs, it makes sense for them to have the same ID.

# %%
# let's see for the second one
df[df['Song ID']=='463CkQjx2Zk1yXoBuierM9']
# Out:
#        Highest Charting Position  Number of Times Charted  \
# Index
# 11                             4                       43
# 101                           52                       19
#
#       Week of Highest Charting                  Song Name   Streams    Artist  \
# Index
# 11      2021-05-07--2021-05-14  Levitating (feat. DaBaby)  23518010  Dua Lipa
# 101     2020-03-27--2020-04-03                 Levitating   6799831  Dua Lipa
#
#       Artist Followers                 Song ID                   Genre  \
# Index
# 11            27142474  463CkQjx2Zk1yXoBuierM9  dance pop, pop, uk pop
# 101           27142474  463CkQjx2Zk1yXoBuierM9  dance pop, pop, uk pop
#
#       Release Date  ... Danceability Energy Loudness Speechiness Acousticness  \
# Index               ...
# 11      2020-10-01  ...        0.702  0.825   -3.787      0.0601      0.00883
# 101     2020-10-01  ...        0.702  0.825   -3.787      0.0601      0.00883
#
#       Liveness    Tempo Duration (ms) Valence  Chord
# Index
# 11      0.0674  102.977        203064   0.915  F#/Gb
# 101     0.0674  102.977        203064   0.915  F#/Gb
#
# [2 rows x 22 columns]

# %% [markdown]
# The same applies here, it is therefore not an error to have duplicate song IDs. We assume it is the same case for the other 27 duplicated song IDs.

# %% [markdown]
# ### Danceability, Energy, Loudness, Speechiness, Acousticness, Liveness, Tempo, Duration, Valence
# There are not in the right format, we cast them to float.

# %%
df[['Danceability', 'Energy', 'Loudness', 'Speechiness', 'Acousticness', 'Liveness', 'Tempo', 
    'Duration (ms)', 'Valence']] = df[['Danceability', 'Energy', 'Loudness', 'Speechiness', 'Acousticness', 'Liveness', 'Tempo', 
    'Duration (ms)', 'Valence']].astype(float)

# %% [markdown]
# ## Statistics

# %%
print('Here are some basic statistics about our data:', end = '\n\n')

print(f'--> There are {len(df)} songs of Spotify in this dataset.', end='\n\n')

first_date = df['Release Date'].min()
last_date = df['Release Date'].max()
print(f'--> The content we have was released between {first_date.year} and {last_date.year}.', end='\n\n')

n_singers = len(df.Artist.unique())
print(f'--> There are {n_singers} unique artists in this Spotify collection.', end='\n\n')

n_genres = len(genre_counts.keys())
print(f'--> There are {n_genres} unique genres.', end='\n\n')
# Out:
# Here are some basic statistics about our data:
#
# --> There are 1545 songs of Spotify in this dataset.
#
# --> The content we have was released between 1942 and 2021.
#
# --> There are 712 unique artists in this Spotify collection.
#
# --> There are 335 unique genres.

# %% [markdown]
# ### Streams per year

# %%
df.plot('Release Date','Streams')
plt.ylabel('Streams')
plt.title('Number of streams per Release date')
plt.show()
print()

# %% [markdown]
# We see the majority of streams are for songs released since 2018 approximately.

# %% [markdown]
# ### Most popular genres

# %%
# !pip install squarify
# Out:
# Requirement already satisfied: squarify in /Users/palomacito/opt/anaconda3/lib/python3.8/site-packages (0.4.3)

# %% [markdown]
# We create a dictionary with the genre that appear more than 50 times in the top 200.

# %%
genre_counts2 = dict((k, v) for k, v in genre_counts.items() if v >= 50)

# %%
fig=plt.figure(figsize=(12,12))
subplot=fig.add_subplot(1,1,1)

norms = squarify.normalize_sizes(list(genre_counts2.values()),  dx=3, dy=3)
squarify.plot(sizes=norms, label=list(genre_counts2.keys()), color=sns.color_palette("Spectral", 
                                     len(genre_counts2)),alpha=1, pad=1,text_kwargs={'fontsize': 10},ax=subplot)
plt.axis("off")
plt.title('Genres with more than 50 occurences')
plt.show()
print()

# %% [markdown]
# ### Artists with most streams

# %% [markdown]
# Let us see which artists had the most streams :

# %%
streams_per_artist = df[['Streams','Artist']].groupby('Artist').sum().sort_values(by='Streams',ascending=True)[-20:]

plt.rcdefaults()
fig, ax = plt.subplots()
ax.barh(streams_per_artist.index, streams_per_artist.Streams,align='center')
ax.set_xlabel('Streams')
ax.set_title('Most popular artists')

plt.show()
print()

# %% [markdown]
# ### Artists that have the most songs

# %% [markdown]
# Now let us see which artists have produced the most songs in this top 200 :

# %%
people = df['Artist'].dropna().explode('Artist')
people_count = people.value_counts(sort = True, ascending = True)
nb_people = people.nunique()
top_people = people_count[-20:]
    
fig, ax = plt.subplots(figsize=(15,10))
top_people.plot.barh(y = top_people, ax=ax)

for i, v in enumerate(top_people):
    ax.text((v/top_people.values.max() - 0.03)*top_people.values.max(), 
                i-0.10, str(v), 
            color = 'white', fontweight = 'bold', fontsize = 'x-small')
        
plt.title('Artists on Spotify with most songs')
plt.ylabel('Artist')
plt.xlabel('Count')
plt.show()

# %% [markdown]
# ### Danceability over time

# %% [markdown]
# We create a new column to simplify the visualization of the properties over time

# %%
df["Release Year"] = df["Release Date"].apply(lambda x : x.year)

# %%
plt.figure(figsize=(15, 5))
plt.title('Danceability over time')
sns.lineplot(data=df, x="Release Year", y="Danceability")
plt.show()
print()

# %% [markdown]
# ### Energy over time

# %%
plt.figure(figsize=(15, 5))
plt.title('Energy over time')
sns.lineplot(data=df, x="Release Year", y="Energy")
plt.show()
print()

# %% [markdown]
# ### Duration over time

# %%
plt.figure(figsize=(15, 5))
plt.title('Duration (ms) over time')
sns.lineplot(data=df, x="Release Year", y="Duration (ms)")
plt.show()
print()

# %% [markdown]
# # Save json files

# %%
df.columns
# Out:
# Index(['Highest Charting Position', 'Number of Times Charted',
#        'Week of Highest Charting', 'Song Name', 'Streams', 'Artist',
#        'Artist Followers', 'Song ID', 'Genre', 'Release Date', 'Weeks Charted',
#        'Popularity', 'Danceability', 'Energy', 'Loudness', 'Speechiness',
#        'Acousticness', 'Liveness', 'Tempo', 'Duration (ms)', 'Valence',
#        'Chord', 'Release Year'],
#       dtype='object')

# %%
streams_per_artist = df[['Streams','Artist']].groupby('Artist').sum().sort_values(by='Streams',ascending=False)[:12]
top_12_artists = streams_per_artist.reset_index()['Artist']
final_dict_top12 = [{'Rank':k+1,'Artist':v,'Top song': '', 'Genres':''} for k, v in top_12_artists.items()]
final_dict_top12
# Out:
# [{'Rank': 1, 'Artist': 'Taylor Swift', 'Top song': '', 'Genres': ''},
#  {'Rank': 2, 'Artist': 'BTS', 'Top song': '', 'Genres': ''},
#  {'Rank': 3, 'Artist': 'Justin Bieber', 'Top song': '', 'Genres': ''},
#  {'Rank': 4, 'Artist': 'Lil Uzi Vert', 'Top song': '', 'Genres': ''},
#  {'Rank': 5, 'Artist': 'Bad Bunny', 'Top song': '', 'Genres': ''},
#  {'Rank': 6, 'Artist': 'Pop Smoke', 'Top song': '', 'Genres': ''},
#  {'Rank': 7, 'Artist': 'Juice WRLD', 'Top song': '', 'Genres': ''},
#  {'Rank': 8, 'Artist': 'Olivia Rodrigo', 'Top song': '', 'Genres': ''},
#  {'Rank': 9, 'Artist': 'Eminem', 'Top song': '', 'Genres': ''},
#  {'Rank': 10, 'Artist': 'The Weeknd', 'Top song': '', 'Genres': ''},
#  {'Rank': 11, 'Artist': 'J. Cole', 'Top song': '', 'Genres': ''},
#  {'Rank': 12, 'Artist': 'Doja Cat', 'Top song': '', 'Genres': ''}]

# %%
name = df[df.Artist == 'Taylor Swift'][['Streams','Song Name']] \
            .sort_values(by='Streams',ascending=False).iloc[0]['Song Name']
name
# Out:
# 'happiness'

# %%
i = 0
for a in top_12_artists:
    final_dict_top12[i]['Top song'] = df[df.Artist == a][['Streams','Song Name']].sort_values(by='Streams',ascending=False).iloc[0]['Song Name']
    final_dict_top12[i]['Genres'] = list(df[df.Artist == a].Genre.unique())
    i += 1

# %%
final_dict_top12
# Out:
# [{'Rank': 1,
#   'Artist': 'Taylor Swift',
#   'Top song': 'happiness',
#   'Genres': ['pop, post-teen pop']},
#  {'Rank': 2,
#   'Artist': 'BTS',
#   'Top song': 'Permission to Dance',
#   'Genres': ['k-pop, k-pop boy group']},
#  {'Rank': 3,
#   'Artist': 'Justin Bieber',
#   'Top song': 'Peaches (feat. Daniel Caesar & Giveon)',
#   'Genres': ['canadian pop, pop, post-teen pop', '']},
#  {'Rank': 4,
#   'Artist': 'Lil Uzi Vert',
#   'Top song': 'That Way',
#   'Genres': ['melodic rap, philly rap, rap, trap']},
#  {'Rank': 5,
#   'Artist': 'Bad Bunny',
#   'Top song': 'Yonaguni',
#   'Genres': ['latin, reggaeton, trap latino']},
#  {'Rank': 6,
#   'Artist': 'Pop Smoke',
#   'Top song': 'Aim For The Moon (feat. Quavo)',
#   'Genres': ['brooklyn drill']},
#  {'Rank': 7,
#   'Artist': 'Juice WRLD',
#   'Top song': 'Real Shit (with benny blanco)',
#   'Genres': ['chicago rap, melodic rap']},
#  {'Rank': 8,
#   'Artist': 'Olivia Rodrigo',
#   'Top song': 'good 4 u',
#   'Genres': ['pop']},
#  {'Rank': 9,
#   'Artist': 'Eminem',
#   'Top song': 'Premonition - Intro',
#   'Genres': ['detroit hip hop, hip hop, rap']},
#  {'Rank': 10,
#   'Artist': 'The Weeknd',
#   'Top song': 'Save Your Tears (with Ariana Grande) (Remix)',
#   'Genres': ['canadian contemporary r&b, canadian pop, pop']},
#  {'Rank': 11,
#   'Artist': 'J. Cole',
#   'Top song': 'a p p l y i n g . p r e s s u r e',
#   'Genres': ['conscious hip hop, hip hop, north carolina hip hop, rap']},
#  {'Rank': 12,
#   'Artist': 'Doja Cat',
#   'Top song': 'Kiss Me More (feat. SZA)',
#   'Genres': ['dance pop, pop']}]

# %%
final_final = {'Artist' : final_dict_top12}
final_final
# Out:
# {'Artist': [{'Rank': 1,
#    'Artist': 'Taylor Swift',
#    'Top song': 'happiness',
#    'Genres': ['pop, post-teen pop']},
#   {'Rank': 2,
#    'Artist': 'BTS',
#    'Top song': 'Permission to Dance',
#    'Genres': ['k-pop, k-pop boy group']},
#   {'Rank': 3,
#    'Artist': 'Justin Bieber',
#    'Top song': 'Peaches (feat. Daniel Caesar & Giveon)',
#    'Genres': ['canadian pop, pop, post-teen pop', '']},
#   {'Rank': 4,
#    'Artist': 'Lil Uzi Vert',
#    'Top song': 'That Way',
#    'Genres': ['melodic rap, philly rap, rap, trap']},
#   {'Rank': 5,
#    'Artist': 'Bad Bunny',
#    'Top song': 'Yonaguni',
#    'Genres': ['latin, reggaeton, trap latino']},
#   {'Rank': 6,
#    'Artist': 'Pop Smoke',
#    'Top song': 'Aim For The Moon (feat. Quavo)',
#    'Genres': ['brooklyn drill']},
#   {'Rank': 7,
#    'Artist': 'Juice WRLD',
#    'Top song': 'Real Shit (with benny blanco)',
#    'Genres': ['chicago rap, melodic rap']},
#   {'Rank': 8,
#    'Artist': 'Olivia Rodrigo',
#    'Top song': 'good 4 u',
#    'Genres': ['pop']},
#   {'Rank': 9,
#    'Artist': 'Eminem',
#    'Top song': 'Premonition - Intro',
#    'Genres': ['detroit hip hop, hip hop, rap']},
#   {'Rank': 10,
#    'Artist': 'The Weeknd',
#    'Top song': 'Save Your Tears (with Ariana Grande) (Remix)',
#    'Genres': ['canadian contemporary r&b, canadian pop, pop']},
#   {'Rank': 11,
#    'Artist': 'J. Cole',
#    'Top song': 'a p p l y i n g . p r e s s u r e',
#    'Genres': ['conscious hip hop, hip hop, north carolina hip hop, rap']},
#   {'Rank': 12,
#    'Artist': 'Doja Cat',
#    'Top song': 'Kiss Me More (feat. SZA)',
#    'Genres': ['dance pop, pop']}]}

# %%
final_dict_top12
# Out:
# [{'Rank': 1,
#   'Artist': 'Taylor Swift',
#   'Top song': 'happiness',
#   'Genres': ['pop, post-teen pop']},
#  {'Rank': 2,
#   'Artist': 'BTS',
#   'Top song': 'Permission to Dance',
#   'Genres': ['k-pop, k-pop boy group']},
#  {'Rank': 3,
#   'Artist': 'Justin Bieber',
#   'Top song': 'Peaches (feat. Daniel Caesar & Giveon)',
#   'Genres': ['canadian pop, pop, post-teen pop', '']},
#  {'Rank': 4,
#   'Artist': 'Lil Uzi Vert',
#   'Top song': 'That Way',
#   'Genres': ['melodic rap, philly rap, rap, trap']},
#  {'Rank': 5,
#   'Artist': 'Bad Bunny',
#   'Top song': 'Yonaguni',
#   'Genres': ['latin, reggaeton, trap latino']},
#  {'Rank': 6,
#   'Artist': 'Pop Smoke',
#   'Top song': 'Aim For The Moon (feat. Quavo)',
#   'Genres': ['brooklyn drill']},
#  {'Rank': 7,
#   'Artist': 'Juice WRLD',
#   'Top song': 'Real Shit (with benny blanco)',
#   'Genres': ['chicago rap, melodic rap']},
#  {'Rank': 8,
#   'Artist': 'Olivia Rodrigo',
#   'Top song': 'good 4 u',
#   'Genres': ['pop']},
#  {'Rank': 9,
#   'Artist': 'Eminem',
#   'Top song': 'Premonition - Intro',
#   'Genres': ['detroit hip hop, hip hop, rap']},
#  {'Rank': 10,
#   'Artist': 'The Weeknd',
#   'Top song': 'Save Your Tears (with Ariana Grande) (Remix)',
#   'Genres': ['canadian contemporary r&b, canadian pop, pop']},
#  {'Rank': 11,
#   'Artist': 'J. Cole',
#   'Top song': 'a p p l y i n g . p r e s s u r e',
#   'Genres': ['conscious hip hop, hip hop, north carolina hip hop, rap']},
#  {'Rank': 12,
#   'Artist': 'Doja Cat',
#   'Top song': 'Kiss Me More (feat. SZA)',
#   'Genres': ['dance pop, pop']}]

# %%
import json
with open('../website/data/top12artists.json', 'w') as f:
    json.dump(final_dict_top12, f,indent=4)

# %%
final_final['Artist'][0]['Artist']
# Out:
# 'Taylor Swift'

# %% [markdown]
# # Music features

# %%
df['Danceability'].to_csv('../website/data/danceability.csv')

# %%
df.columns
# Out:
# Index(['Highest Charting Position', 'Number of Times Charted',
#        'Week of Highest Charting', 'Song Name', 'Streams', 'Artist',
#        'Artist Followers', 'Song ID', 'Genre', 'Release Date', 'Weeks Charted',
#        'Popularity', 'Danceability', 'Energy', 'Loudness', 'Speechiness',
#        'Acousticness', 'Liveness', 'Tempo', 'Duration (ms)', 'Valence',
#        'Chord', 'Release Year'],
#       dtype='object')

# %%
df['Energy'].to_csv('../website/data/energy.csv')

# %%
df['Loudness'].to_csv('../website/data/loudness.csv')

# %%
df['Speechiness'].to_csv('../website/data/speechiness.csv')

# %%
df['Acousticness'].to_csv('../website/data/acousticness.csv')

# %%
df['Liveness'].to_csv('../website/data/liveness.csv')

# %% [markdown]
# # Genres dependencies

# %%
len(df.Genre.unique())
# Out:
# 394

# %%
unique_genres = [x for x in df.Genre.unique() if "," not in x]

# %%
genre_freq = dict.fromkeys(unique_genres,0)

# %%
for g in genre_freq.keys():
    for g_list in df.Genre:
        if g in g_list:
            genre_freq[g] += 1

# %%
top20_genres = sorted(genre_freq, key=genre_freq.get, reverse=True)[1:21]
top20_genres
# Out:
# ['pop',
#  'reggaeton',
#  'pop rap',
#  'trap latino',
#  'melodic rap',
#  'german hip hop',
#  'k-pop',
#  'chicago rap',
#  'tropical house',
#  'brooklyn drill',
#  'modern rock',
#  'k-pop girl group',
#  'latin pop',
#  'funk carioca',
#  'trap queen',
#  'contemporary country',
#  'electro house',
#  'australian pop',
#  'trap argentino',
#  'uk hip hop']

# %%
final_dep = {}

# %%
import networkx as nx
G = nx.Graph()
G.add_nodes_from(df.Genre.unique())

# %%
for g_list in df.Genre:
    l = g_list.split(',')
    if len(l) == 2:
        if (l[0],l[1]) not in G.edges:
            G.add_edge(l[0],l[1],weight=1)
        else:
            G[l[0]][l[1]]['weight'] += 1
    if len(l) == 3:
        if (l[0],l[1]) not in G.edges:
            G.add_edge(l[0],l[1],weight=1)
        else:
            G[l[0]][l[1]]['weight'] += 1
        if (l[0],l[2]) not in G.edges:
            G.add_edge(l[0],l[2],weight=1)
        else:
            G[l[0]][l[2]]['weight'] += 1
        if (l[1],l[2]) not in G.edges:
            G.add_edge(l[1],l[2],weight=1)
        else:
            G[l[1]][l[2]]['weight'] += 1

# %%
G.number_of_edges()
# Out:
# 223

# %%
list(G.edges)
# Out:
# [('pop', ' uk pop'),
#  ('pop', ' post-teen pop'),
#  ('pop', ' pop rock'),
#  ('pop', ' r&b'),
#  ('pop', ' pop rap'),
#  ('pop', ' soul'),
#  ('chicago rap', ' melodic rap'),
#  ('chicago rap', ' rap'),
#  ('trap argentino', ' trap latino'),
#  ('trap argentino', ' trap triste'),
#  ('german hip hop', ' hamburg hip hop'),
#  ('german hip hop', ' german pop'),
#  ('latin pop', ' pop argentino'),
#  ('latin pop', ' viral pop'),
#  ('latin pop', ' puerto rican pop'),
#  ('brooklyn drill', ' nyc rap'),
#  ('brooklyn drill', ' melodic rap'),
#  ('reggaeton', ' trap latino'),
#  ('reggaeton', ' reggaeton flow'),
#  ('australian pop', ' pop'),
#  ('eurovision', ' nouvelle chanson francaise'),
#  ('eurovision', ' oulu metal'),
#  ('eurovision', ' trancecore'),
#  ('dream smp', ' viral rap'),
#  ('forro', ' sertanejo pop'),
#  ('forro', ' piseiro'),
#  ('bedroom pop', ' indie pop'),
#  ('bedroom pop', ' pop'),
#  ('sertanejo pop', ' sertanejo universitario'),
#  ('contemporary country', ' country road'),
#  ('contemporary country', ' country'),
#  ('contemporary country', ' pop'),
#  ('melodic rap', ' rap'),
#  ('melodic rap', ' trap'),
#  ('melodic rap', ' pop rap'),
#  ('pop rap', ' rap'),
#  ('pop rap', ' trap'),
#  ('pop rap', ' rhode island rap'),
#  ('funk carioca', ' pop nacional'),
#  ('funk carioca', ' funk ostentacao'),
#  ('funk carioca', ' funk paulista'),
#  ('funk carioca', ' rave funk'),
#  ('funk carioca', ' funk pop'),
#  ('k-pop', ' k-pop boy group'),
#  ('k-pop', ' k-pop girl group'),
#  ('modern rock', ' pop'),
#  ('modern rock', ' rock'),
#  ('modern rock', ' uk pop'),
#  ('modern rock', ' pop rap'),
#  ('modern rock', ' seattle hip hop'),
#  ('italian hip hop', ' italian pop'),
#  ('italian hip hop', ' trap italiana'),
#  ('electro house', ' pop nacional'),
#  ('electro house', ' slap house'),
#  ('indie rock italiano', ' italian pop'),
#  (' italian pop', 'italian adult pop'),
#  (' italian pop', ' trap italiana'),
#  (' uk pop', 'dance pop'),
#  (' uk pop', ' pop'),
#  ('lgbtq+ hip hop', ' pop rap'),
#  (' pop rap', ' r&b'),
#  (' pop rap', 'dance pop'),
#  (' pop rap', ' seattle hip hop'),
#  (' pop rap', 'ohio hip hop'),
#  (' pop rap', ' pop'),
#  (' pop rap', 'electropop'),
#  (' pop rap', 'hip hop'),
#  (' pop rap', ' rap'),
#  (' pop rap', 'alternative r&b'),
#  (' pop rap', ' melodic rap'),
#  ('dance pop', ' pop'),
#  ('dance pop', ' post-teen pop'),
#  (' pop', 'canadian pop'),
#  (' pop', ' post-teen pop'),
#  (' pop', 'canadian contemporary r&b'),
#  (' pop', ' canadian pop'),
#  (' pop', 'electropop'),
#  (' pop', 'modern alternative rock'),
#  (' pop', ' modern rock'),
#  (' pop', 'colombian pop'),
#  (' pop', ' rock'),
#  (' pop', 'irish singer-songwriter'),
#  (' pop', 'permanent wave'),
#  (' pop', ' escape room'),
#  (' pop', 'bedroom soul'),
#  (' pop', 'art pop'),
#  (' pop', ' indie pop'),
#  (' pop', ' country'),
#  (' pop', 'indie poptimism'),
#  (' pop', 'canadian hip hop'),
#  (' pop', 'alt z'),
#  (' pop', ' nz pop'),
#  (' pop', ' electropop'),
#  (' pop', 'alternative pop rock'),
#  (' pop', 'chill r&b'),
#  ('puerto rican pop', ' trap latino'),
#  (' trap latino', 'latin'),
#  (' trap latino', ' reggaeton'),
#  (' trap latino', ' reggaeton flow'),
#  (' trap latino', ' trap triste'),
#  (' trap latino', 'argentine hip hop'),
#  (' trap latino', ' trap argentino'),
#  (' trap latino', 'trap chileno'),
#  ('latin', ' reggaeton'),
#  ('latin', ' reggaeton colombiano'),
#  ('latin', ' latin pop'),
#  ('latin', ' puerto rican pop'),
#  (' reggaeton', ' reggaeton colombiano'),
#  (' reggaeton colombiano', 'colombian pop'),
#  ('canadian pop', ' post-teen pop'),
#  ('canadian contemporary r&b', ' canadian pop'),
#  ('gauze pop', ' indietronica'),
#  ('gauze pop', ' shiver pop'),
#  (' indietronica', ' shiver pop'),
#  ('dfw rap', ' melodic rap'),
#  ('dfw rap', ' rap'),
#  (' melodic rap', ' rap'),
#  (' melodic rap', ' nyc rap'),
#  (' melodic rap', 'alternative r&b'),
#  (' rap', ' trap'),
#  (' rap', 'north carolina hip hop'),
#  (' rap', 'detroit hip hop'),
#  (' rap', ' hip hop'),
#  (' rap', 'hip hop'),
#  (' rap', 'emo rap'),
#  (' rap', 'boy band'),
#  (' rap', ' pittsburgh rap'),
#  ('electropop', ' escape room'),
#  ('house', ' pop dance'),
#  ('house', ' uk dance'),
#  (' pop dance', ' uk dance'),
#  (' pop rock', 'neo mellow'),
#  (' pop rock', ' singer-songwriter'),
#  (' r&b', 'pop r&b'),
#  (' r&b', ' soul'),
#  ('modern alternative rock', ' modern rock'),
#  (' modern rock', 'irish singer-songwriter'),
#  ('canadian hip hop', ' toronto rap'),
#  ('mexican hip hop', ' rap conciencia'),
#  ('rap', ' slap house'),
#  ('rap', ' trap'),
#  (' slap house', ' pop nacional'),
#  ('melanesian pop', ' pacific islands pop'),
#  ('melanesian pop', ' png pop'),
#  (' pacific islands pop', ' png pop'),
#  (' rock', 'grunge'),
#  (' rock', ' permanent wave'),
#  (' rock', 'classic rock'),
#  (' rock', ' glam rock'),
#  (' rock', 'australian rock'),
#  (' rock', ' hard rock'),
#  ('chill r&b', ' nyc pop'),
#  ('sertanejo', ' sertanejo pop'),
#  ('sertanejo', ' sertanejo universitario'),
#  (' sertanejo pop', ' sertanejo universitario'),
#  ('grunge', ' permanent wave'),
#  ('classic rock', ' glam rock'),
#  ('plugg', ' vapor trap'),
#  ('plugg', ' viral rap'),
#  (' vapor trap', ' viral rap'),
#  ('art pop', ' norwegian pop'),
#  ('funk bh', ' funk carioca'),
#  (' funk carioca', 'funk 150 bpm'),
#  (' funk carioca', 'brega funk'),
#  ('detroit hip hop', ' hip hop'),
#  (' hip hop', 'boy band'),
#  ('hip hop', ' pittsburgh rap'),
#  ('neo mellow', ' singer-songwriter'),
#  (' funk ostentacao', ' funk paulista'),
#  (' funk ostentacao', 'brazilian hip hop'),
#  (' funk paulista', ' rave funk'),
#  ('eau claire indie', ' folktronica'),
#  ('frauenrap', ' german hip hop'),
#  ('frauenrap', ' german pop'),
#  (' german hip hop', ' german pop'),
#  (' german hip hop', 'german cloud rap'),
#  (' german hip hop', 'german drill'),
#  (' german hip hop', 'christlicher rap'),
#  (' german hip hop', 'albanian hip hop'),
#  (' german hip hop', 'deep german hip hop'),
#  (' german hip hop', ' hamburg hip hop'),
#  (' german pop', ' hamburg hip hop'),
#  ('emo rap', ' miami hip hop'),
#  ('emo rap', ' lgbtq+ hip hop'),
#  (' oulu metal', ' trancecore'),
#  ('icelandic pop', ' sunnlensk tonlist'),
#  (' hamburg hip hop', 'deep german hip hop'),
#  ('indie pop', ' vancouver indie'),
#  ('edm', ' electronic trap'),
#  ('australian psych', ' neo-psychedelic'),
#  (' viral pop', 'alternative r&b'),
#  (' puerto rican pop', ' latin pop'),
#  ('adult standards', ' easy listening'),
#  ('adult standards', ' lounge'),
#  ('adult standards', ' american folk revival'),
#  (' easy listening', ' lounge'),
#  ('rock-and-roll', ' rockabilly'),
#  ('glam rock', ' mellow gold'),
#  ('glam rock', ' piano rock'),
#  (' mellow gold', ' piano rock'),
#  ('hollywood', ' show tunes'),
#  ('motown', ' soul'),
#  ('alt z', ' modern indie pop'),
#  ('alt z', ' social media pop'),
#  ('alt z', ' nz pop'),
#  ('alt z', ' electropop'),
#  (' modern indie pop', ' social media pop'),
#  (' social media pop', 'afroswing'),
#  ('basshall', ' francoton'),
#  ('basshall', ' turkish trap'),
#  ('australian rock', ' hard rock'),
#  ('argentine hip hop', ' trap argentino'),
#  ('r&b brasileiro', ' rap cearense'),
#  ('r&b brasileiro', ' trap brasileiro'),
#  (' rap cearense', ' trap brasileiro'),
#  ('scandipop', ' swedish pop'),
#  ('dominican pop', ' pop reggaeton'),
#  ('dominican pop', ' urbano espanol'),
#  (' pop reggaeton', ' urbano espanol'),
#  ('french hip hop', ' pop urbaine'),
#  ('french hip hop', ' rap francais'),
#  (' pop urbaine', ' rap francais'),
#  ('grime', ' uk hip hop')]

# %%
edges=sorted(G.edges(data=True), key=lambda t: t[2].get('weight', 1),reverse=True)

# %%
edges
# Out:
# [('dance pop', ' pop', {'weight': 223}),
#  (' pop', ' post-teen pop', {'weight': 207}),
#  ('latin', ' reggaeton', {'weight': 185}),
#  ('dance pop', ' post-teen pop', {'weight': 143}),
#  (' trap latino', 'latin', {'weight': 127}),
#  (' trap latino', ' reggaeton', {'weight': 127}),
#  ('pop', ' post-teen pop', {'weight': 115}),
#  ('chicago rap', ' melodic rap', {'weight': 65}),
#  (' pop', 'canadian pop', {'weight': 65}),
#  ('canadian pop', ' post-teen pop', {'weight': 65}),
#  ('k-pop', ' k-pop boy group', {'weight': 61}),
#  ('latin', ' reggaeton colombiano', {'weight': 59}),
#  (' reggaeton', ' reggaeton colombiano', {'weight': 59}),
#  (' rap', 'hip hop', {'weight': 55}),
#  (' pop', 'canadian contemporary r&b', {'weight': 47}),
#  (' pop', ' canadian pop', {'weight': 47}),
#  ('canadian contemporary r&b', ' canadian pop', {'weight': 47}),
#  (' rap', ' hip hop', {'weight': 47}),
#  (' rap', 'detroit hip hop', {'weight': 45}),
#  ('detroit hip hop', ' hip hop', {'weight': 45}),
#  (' pop', 'electropop', {'weight': 37}),
#  (' rap', ' trap', {'weight': 37}),
#  ('melodic rap', ' trap', {'weight': 33}),
#  ('rap', ' trap', {'weight': 31}),
#  (' uk pop', 'dance pop', {'weight': 29}),
#  (' uk pop', ' pop', {'weight': 29}),
#  ('puerto rican pop', ' trap latino', {'weight': 29}),
#  (' rap', 'north carolina hip hop', {'weight': 29}),
#  ('melodic rap', ' rap', {'weight': 27}),
#  ('k-pop', ' k-pop girl group', {'weight': 27}),
#  ('pop', ' uk pop', {'weight': 23}),
#  (' rap', ' pittsburgh rap', {'weight': 23}),
#  ('hip hop', ' pittsburgh rap', {'weight': 23}),
#  ('dfw rap', ' melodic rap', {'weight': 21}),
#  ('dfw rap', ' rap', {'weight': 21}),
#  (' melodic rap', ' rap', {'weight': 21}),
#  ('rap', ' slap house', {'weight': 21}),
#  (' viral pop', 'alternative r&b', {'weight': 21}),
#  ('german hip hop', ' hamburg hip hop', {'weight': 19}),
#  ('modern rock', ' rock', {'weight': 19}),
#  (' reggaeton colombiano', 'colombian pop', {'weight': 19}),
#  ('sertanejo', ' sertanejo universitario', {'weight': 19}),
#  (' pop rap', ' pop', {'weight': 17}),
#  ('brooklyn drill', ' nyc rap', {'weight': 15}),
#  ('lgbtq+ hip hop', ' pop rap', {'weight': 15}),
#  (' german hip hop', 'german cloud rap', {'weight': 15}),
#  ('emo rap', ' miami hip hop', {'weight': 15}),
#  ('pop', ' pop rock', {'weight': 13}),
#  (' pop rap', 'ohio hip hop', {'weight': 13}),
#  ('pop', ' r&b', {'weight': 11}),
#  ('pop rap', ' rap', {'weight': 11}),
#  ('pop rap', ' trap', {'weight': 11}),
#  ('italian hip hop', ' italian pop', {'weight': 11}),
#  ('italian hip hop', ' trap italiana', {'weight': 11}),
#  (' pop rap', 'dance pop', {'weight': 11}),
#  (' pop rap', 'electropop', {'weight': 11}),
#  ('australian psych', ' neo-psychedelic', {'weight': 11}),
#  ('brooklyn drill', ' melodic rap', {'weight': 9}),
#  ('reggaeton', ' trap latino', {'weight': 9}),
#  ('modern rock', ' pop', {'weight': 9}),
#  ('indie rock italiano', ' italian pop', {'weight': 9}),
#  (' italian pop', ' trap italiana', {'weight': 9}),
#  (' pop', ' modern rock', {'weight': 9}),
#  (' pop', ' rock', {'weight': 9}),
#  (' melodic rap', ' nyc rap', {'weight': 9}),
#  (' rap', 'emo rap', {'weight': 9}),
#  ('sertanejo', ' sertanejo pop', {'weight': 9}),
#  (' sertanejo pop', ' sertanejo universitario', {'weight': 9}),
#  (' german hip hop', 'german drill', {'weight': 9}),
#  ('pop', ' pop rap', {'weight': 7}),
#  ('german hip hop', ' german pop', {'weight': 7}),
#  ('forro', ' piseiro', {'weight': 7}),
#  (' pop rap', ' r&b', {'weight': 7}),
#  (' pop', 'modern alternative rock', {'weight': 7}),
#  (' pop', 'art pop', {'weight': 7}),
#  ('modern alternative rock', ' modern rock', {'weight': 7}),
#  (' rock', 'classic rock', {'weight': 7}),
#  (' rock', ' glam rock', {'weight': 7}),
#  ('classic rock', ' glam rock', {'weight': 7}),
#  ('frauenrap', ' german hip hop', {'weight': 7}),
#  ('frauenrap', ' german pop', {'weight': 7}),
#  (' german hip hop', ' german pop', {'weight': 7}),
#  ('adult standards', ' easy listening', {'weight': 7}),
#  ('adult standards', ' lounge', {'weight': 7}),
#  (' easy listening', ' lounge', {'weight': 7}),
#  ('australian pop', ' pop', {'weight': 5}),
#  ('sertanejo pop', ' sertanejo universitario', {'weight': 5}),
#  ('contemporary country', ' country road', {'weight': 5}),
#  ('pop rap', ' rhode island rap', {'weight': 5}),
#  ('funk carioca', ' funk ostentacao', {'weight': 5}),
#  ('funk carioca', ' funk paulista', {'weight': 5}),
#  (' pop rap', 'hip hop', {'weight': 5}),
#  (' pop rap', ' rap', {'weight': 5}),
#  (' pop', 'permanent wave', {'weight': 5}),
#  (' pop', ' escape room', {'weight': 5}),
#  (' pop', 'bedroom soul', {'weight': 5}),
#  (' pop', 'canadian hip hop', {'weight': 5}),
#  (' pop', 'alt z', {'weight': 5}),
#  ('electropop', ' escape room', {'weight': 5}),
#  (' pop rock', 'neo mellow', {'weight': 5}),
#  (' pop rock', ' singer-songwriter', {'weight': 5}),
#  (' funk carioca', 'brega funk', {'weight': 5}),
#  ('neo mellow', ' singer-songwriter', {'weight': 5}),
#  (' german hip hop', 'albanian hip hop', {'weight': 5}),
#  ('basshall', ' francoton', {'weight': 5}),
#  ('pop', ' soul', {'weight': 3}),
#  ('chicago rap', ' rap', {'weight': 3}),
#  ('trap argentino', ' trap latino', {'weight': 3}),
#  ('trap argentino', ' trap triste', {'weight': 3}),
#  ('latin pop', ' pop argentino', {'weight': 3}),
#  ('latin pop', ' viral pop', {'weight': 3}),
#  ('latin pop', ' puerto rican pop', {'weight': 3}),
#  ('reggaeton', ' reggaeton flow', {'weight': 3}),
#  ('eurovision', ' nouvelle chanson francaise', {'weight': 3}),
#  ('eurovision', ' oulu metal', {'weight': 3}),
#  ('eurovision', ' trancecore', {'weight': 3}),
#  ('dream smp', ' viral rap', {'weight': 3}),
#  ('forro', ' sertanejo pop', {'weight': 3}),
#  ('bedroom pop', ' indie pop', {'weight': 3}),
#  ('bedroom pop', ' pop', {'weight': 3}),
#  ('contemporary country', ' country', {'weight': 3}),
#  ('contemporary country', ' pop', {'weight': 3}),
#  ('melodic rap', ' pop rap', {'weight': 3}),
#  ('funk carioca', ' pop nacional', {'weight': 3}),
#  ('funk carioca', ' rave funk', {'weight': 3}),
#  ('funk carioca', ' funk pop', {'weight': 3}),
#  ('modern rock', ' uk pop', {'weight': 3}),
#  ('modern rock', ' pop rap', {'weight': 3}),
#  ('modern rock', ' seattle hip hop', {'weight': 3}),
#  ('electro house', ' pop nacional', {'weight': 3}),
#  ('electro house', ' slap house', {'weight': 3}),
#  (' italian pop', 'italian adult pop', {'weight': 3}),
#  (' pop rap', ' seattle hip hop', {'weight': 3}),
#  (' pop rap', 'alternative r&b', {'weight': 3}),
#  (' pop rap', ' melodic rap', {'weight': 3}),
#  (' pop', 'colombian pop', {'weight': 3}),
#  (' pop', 'irish singer-songwriter', {'weight': 3}),
#  (' pop', ' indie pop', {'weight': 3}),
#  (' pop', ' country', {'weight': 3}),
#  (' pop', 'indie poptimism', {'weight': 3}),
#  (' pop', ' nz pop', {'weight': 3}),
#  (' pop', ' electropop', {'weight': 3}),
#  (' pop', 'alternative pop rock', {'weight': 3}),
#  (' pop', 'chill r&b', {'weight': 3}),
#  (' trap latino', ' reggaeton flow', {'weight': 3}),
#  (' trap latino', ' trap triste', {'weight': 3}),
#  (' trap latino', 'argentine hip hop', {'weight': 3}),
#  (' trap latino', ' trap argentino', {'weight': 3}),
#  (' trap latino', 'trap chileno', {'weight': 3}),
#  ('latin', ' latin pop', {'weight': 3}),
#  ('latin', ' puerto rican pop', {'weight': 3}),
#  ('gauze pop', ' indietronica', {'weight': 3}),
#  ('gauze pop', ' shiver pop', {'weight': 3}),
#  (' indietronica', ' shiver pop', {'weight': 3}),
#  (' melodic rap', 'alternative r&b', {'weight': 3}),
#  (' rap', 'boy band', {'weight': 3}),
#  ('house', ' pop dance', {'weight': 3}),
#  ('house', ' uk dance', {'weight': 3}),
#  (' pop dance', ' uk dance', {'weight': 3}),
#  (' r&b', 'pop r&b', {'weight': 3}),
#  (' r&b', ' soul', {'weight': 3}),
#  (' modern rock', 'irish singer-songwriter', {'weight': 3}),
#  ('canadian hip hop', ' toronto rap', {'weight': 3}),
#  ('mexican hip hop', ' rap conciencia', {'weight': 3}),
#  (' slap house', ' pop nacional', {'weight': 3}),
#  ('melanesian pop', ' pacific islands pop', {'weight': 3}),
#  ('melanesian pop', ' png pop', {'weight': 3}),
#  (' pacific islands pop', ' png pop', {'weight': 3}),
#  (' rock', 'grunge', {'weight': 3}),
#  (' rock', ' permanent wave', {'weight': 3}),
#  (' rock', 'australian rock', {'weight': 3}),
#  (' rock', ' hard rock', {'weight': 3}),
#  ('chill r&b', ' nyc pop', {'weight': 3}),
#  ('grunge', ' permanent wave', {'weight': 3}),
#  ('plugg', ' vapor trap', {'weight': 3}),
#  ('plugg', ' viral rap', {'weight': 3}),
#  (' vapor trap', ' viral rap', {'weight': 3}),
#  ('art pop', ' norwegian pop', {'weight': 3}),
#  ('funk bh', ' funk carioca', {'weight': 3}),
#  (' funk carioca', 'funk 150 bpm', {'weight': 3}),
#  (' hip hop', 'boy band', {'weight': 3}),
#  (' funk ostentacao', ' funk paulista', {'weight': 3}),
#  (' funk ostentacao', 'brazilian hip hop', {'weight': 3}),
#  (' funk paulista', ' rave funk', {'weight': 3}),
#  ('eau claire indie', ' folktronica', {'weight': 3}),
#  (' german hip hop', 'christlicher rap', {'weight': 3}),
#  (' german hip hop', 'deep german hip hop', {'weight': 3}),
#  (' german hip hop', ' hamburg hip hop', {'weight': 3}),
#  (' german pop', ' hamburg hip hop', {'weight': 3}),
#  ('emo rap', ' lgbtq+ hip hop', {'weight': 3}),
#  (' oulu metal', ' trancecore', {'weight': 3}),
#  ('icelandic pop', ' sunnlensk tonlist', {'weight': 3}),
#  (' hamburg hip hop', 'deep german hip hop', {'weight': 3}),
#  ('indie pop', ' vancouver indie', {'weight': 3}),
#  ('edm', ' electronic trap', {'weight': 3}),
#  (' puerto rican pop', ' latin pop', {'weight': 3}),
#  ('adult standards', ' american folk revival', {'weight': 3}),
#  ('rock-and-roll', ' rockabilly', {'weight': 3}),
#  ('glam rock', ' mellow gold', {'weight': 3}),
#  ('glam rock', ' piano rock', {'weight': 3}),
#  (' mellow gold', ' piano rock', {'weight': 3}),
#  ('hollywood', ' show tunes', {'weight': 3}),
#  ('motown', ' soul', {'weight': 3}),
#  ('alt z', ' modern indie pop', {'weight': 3}),
#  ('alt z', ' social media pop', {'weight': 3}),
#  ('alt z', ' nz pop', {'weight': 3}),
#  ('alt z', ' electropop', {'weight': 3}),
#  (' modern indie pop', ' social media pop', {'weight': 3}),
#  (' social media pop', 'afroswing', {'weight': 3}),
#  ('basshall', ' turkish trap', {'weight': 3}),
#  ('australian rock', ' hard rock', {'weight': 3}),
#  ('argentine hip hop', ' trap argentino', {'weight': 3}),
#  ('r&b brasileiro', ' rap cearense', {'weight': 3}),
#  ('r&b brasileiro', ' trap brasileiro', {'weight': 3}),
#  (' rap cearense', ' trap brasileiro', {'weight': 3}),
#  ('scandipop', ' swedish pop', {'weight': 3}),
#  ('dominican pop', ' pop reggaeton', {'weight': 3}),
#  ('dominican pop', ' urbano espanol', {'weight': 3}),
#  (' pop reggaeton', ' urbano espanol', {'weight': 3}),
#  ('french hip hop', ' pop urbaine', {'weight': 3}),
#  ('french hip hop', ' rap francais', {'weight': 3}),
#  (' pop urbaine', ' rap francais', {'weight': 3}),
#  ('grime', ' uk hip hop', {'weight': 3})]
